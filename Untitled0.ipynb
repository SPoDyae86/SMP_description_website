# %% [markdown]
# <a href="https://colab.research.google.com/github/SPoDyae86/SMP_description_website/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
f=["apple","kiwi","banana","peach","pear"]
if "orange" in f:
# Out:
#   File "<ipython-input-1-69905525e630>", line 2
#     if "orange" in f:
#                      ^
# SyntaxError: unexpected EOF while parsing

# %%
print

# %%
a=int(input("enter your marks worth"))
b=int(input("enter your marks two"))
a+b
# Out:
# enter your marks worth12
# enter your marks two2
# 14

# %%
def bhg():
  print("hello")
bhg()
# Out:
# hello

# %%
from google.collab import files
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-e72911b30bc6> in <module>()
# ----> 1 from google.collab import files
#
# ModuleNotFoundError: No module named 'google.collab'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-91dd14a0-25d3-4782-bec0-370d75bbe78f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-91dd14a0-25d3-4782-bec0-370d75bbe78f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving newPythonThing.txt to newPythonThing.txt
# {'newPythonThing.txt': b''}

# %%
f=open("newPythonThing.txt")
reader=f.readlines()
for x in reader:
  print(x)

# %% [markdown]
# os and shutil module

# %%
# !pip install howdoi
# Out:
# ...
#      |████████████████████████████████| 291 kB 8.3 MB/s
# ...
#      |████████████████████████████████| 961 kB 43.7 MB/s
# ...
#   Created wheel for howdoi: filename=howdoi-2.0.17-py3-none-any.whl size=15845 sha256=36973858b893658ecbe0fd5caf4b55bb388dfe7940eb0dea9ef8626b2dbd96f7
#   Stored in directory: /root/.cache/pip/wheels/d7/4c/b3/512807f35ac51ef39e05edf60db42529f68a3cd214cc10fc1b
# ...
#   Created wheel for terminaltables: filename=terminaltables-3.1.0-py3-none-any.whl size=15354 sha256=49c9b60581005e303b0c6d47ae19b1278f2f4bbaf1133f40d6e7702bb9f88097
#   Stored in directory: /root/.cache/pip/wheels/ba/ad/c8/2d98360791161cd3db6daf6b5e730f34021fc9367d5879f497
# Successfully built howdoi terminaltables
# ...

# %%
howdoi write functions in python
# Out:
#   File "<ipython-input-2-81ea10564c65>", line 1
#     howdoi write functions in python
#                ^
# SyntaxError: invalid syntax

# %%
def bhg():
  print("hello")
bhg()

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-f8a4f041-c564-4d27-85cd-446b96b14d5f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f8a4f041-c564-4d27-85cd-446b96b14d5f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving data.csv to data.csv
# ...

# %%
import pandas as pd

import plotly.express as px

#reading data from csv files
df = pd.read_csv("data.csv")
fig = px.bar(df, x='Country', y='InternetUsers')
fig.show()
# Out:
#   File "<ipython-input-5-6bc8414da421>", line 13
#     fig.show()
#       ^
# SyntaxError: invalid syntax

# %%
import

# %%
import pandas as pd
import plotly.express as px
df = pd.read_csv("data.csv")
fig = px.bar(df, x='InternetUsers', y='Country')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="07565355-d3e0-4359-a0ff-0f9f2aeb0b54" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("07565355-d3e0-4359-a0ff-0f9f2aeb0b54")) {
#                     Plotly.newPlot(
#                         '07565355-d3e0-4359-a0ff-0f9f2aeb0b54',
# ...

# %%
10//2
# Out:
# 5

# %%
10//2.5
# Out:
# 4.0

# %%
10/2.5
# Out:
# 4.0

# %%
3//6
# Out:
# 0

# %%
6//3
# Out:
# 2

# %%
6/3
# Out:
# 2.0

# %%
3/6
# Out:
# 0.5

# %%
m = [1,2,3,4]
n = 4
median1 = m[m//2]
median1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-b3010396a6b8> in <module>()
#       1 m = [1,2,3,4]
#       2 n = 4
# ----> 3 median1 = m[m//2]
#       4 median1
#
# TypeError: unsupported operand type(s) for //: 'list' and 'int'

# %%
#the code will print multiple modes, should there be more than one.
from collections import Counter
import csv

with open('height-and-weight.csv', newline='') as f:
    reader = csv.reader(f)
    file_data = list(reader)

file_data.pop(0)
#removes the header, so that only the actual values remain.
new_data=[]
for i in range(len(file_data)):
	n_num = file_data[i][1]
	new_data.append(n_num)
n = len(new_data)
data = Counter(new_data)
get_mode = dict(data)

mode = []
mode1 = []
mode2 = []
for a,v in get_mode.items():
    a= float(a)
    if 50< a <60:
        if v == max(list(data.values())):
            mode.append(a)
    elif 60< a <70:
        if v == max(list(data.values())):
            mode1.append(a)
    elif 70< a <75:
        if v == max(list(data.values())):
            mode2.append(a)



if len(mode)>len(mode1) and len(mode2):
    print("The Mode(s) is /are "+ ', '.join(map(str, mode)))
elif len(mode1)>len(mode) and len(mode2):
    print("The Mode(s) is /are "+ ', '.join(map(str, mode1)))
elif len(mode2)>len(mode) and len(mode1):
    print("The Mode(s) is /are "+ ', '.join(map(str, mode2)))

# print(get_mode "is the mode")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-9a4724050def> in <module>()
#       3 import csv
#       4
# ----> 5 with open('height-and-weight.csv', newline='') as f:
#       6     reader = csv.reader(f)
#       7     file_data = list(reader)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'height-and-weight.csv'

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-cc96b472-30cb-4702-9994-f03036c06575" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cc96b472-30cb-4702-9994-f03036c06575">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving height-and-weight.csv to height-and-weight.csv
# ...

# %%
#the code will print multiple modes, should there be more than one.
from collections import Counter
import csv

with open('height-and-weight.csv', newline='') as f:
    reader = csv.reader(f)
    file_data = list(reader)

file_data.pop(0)
#removes the header, so that only the actual values remain.
new_data=[]
for i in range(len(file_data)):
	n_num = file_data[i][1]
	new_data.append(n_num)
n = len(new_data)
data = Counter(new_data)
get_mode = dict(data)

mode = []
mode1 = []
mode2 = []
for a,v in get_mode.items():
    a= float(a)
    if 50< a <60:
        if v == max(list(data.values())):
            mode.append(a)
    elif 60< a <70:
        if v == max(list(data.values())):
            mode1.append(a)
    elif 70< a <75:
        if v == max(list(data.values())):
            mode2.append(a)



if len(mode)>len(mode1) and len(mode2):
    print("The Mode(s) is /are "+ ', '.join(map(str, mode)))
elif len(mode1)>len(mode) and len(mode2):
    print("The Mode(s) is /are "+ ', '.join(map(str, mode1)))
elif len(mode2)>len(mode) and len(mode1):
    print("The Mode(s) is /are "+ ', '.join(map(str, mode2)))

# print(get_mode "is the mode")
# Out:
# The Mode(s) is /are 67.94061, 65.65796, 68.9238, 67.98509, 68.9783, 68.93456, 67.41672, 67.97769, 67.34629, 68.30287

# %%
list = [1,2,3,4,5,6,7,8]
n = 8
#getting the first number
median1 = new_data[n//2]
    #getting the second number
median2 = new_data[n//2 - 1]
    #getting mean of those numbers
median1
median2
# Out:
# '68.2166'

# %%
median1
# Out:
# '67.78781'

# %%
median2
# Out:
# '68.2166'

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-9223110f-d138-4c00-af34-f031aaa90300" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9223110f-d138-4c00-af34-f031aaa90300">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Student Marks vs Days Present.csv to Student Marks vs Days Present.csv
# {'Student Marks vs Days Present.csv': b'Roll No,Marks In Percentage,Days Present\n1,79,180\n2,73,160\n3,71,155\n4,71.6,156\n5,59.59,145\n6,30,122\n7,35,131\n8,44,156\n9,60,166\n10,60,170\n11,60,155\n12,63,158\n13,78,170\n14,63,160\n15,77,165\n16,54,159\n17,20,119\n18,65,168\n19,78,175\n20,55.99,161\n21,70,160\n22,68,160\n23,46,150\n24,50,140\n25,47,148\n'}

# %%
import csv
import numpy as np


def getDataSource(data_path):
    marks_in_percentage = []
    days_present = []
    with open(data_path) as csv_file:
        csv_reader = csv.DictReader(csv_file)
        for row in csv_reader:
            marks_in_percentage.append(float(row["Marks In Percentage"]))
            days_present.append(float(row["Days Present"]))

    return {"x" : marks_in_percentage, "y": days_present}

def findCorrelation(datasource):
    correlation = np.corrcoef(datasource["x"], datasource["y"])
    print("Correlation between Marks in percentage and Days present :-  \n--->",correlation[0,1])

def setup():
    data_path  = "Student Marks vs Days Present.csv"

    datasource = getDataSource(data_path)
    findCorrelation(datasource)

setup()
# Out:
# Correlation between Marks in percentage and Days present :-
# ---> 0.86288947614385

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-ea907219-a6b4-4628-ab9b-8852f6b9960d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ea907219-a6b4-4628-ab9b-8852f6b9960d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving cups of coffee vs hours of sleep.csv to cups of coffee vs hours of sleep (1).csv
# Saving Ice-Cream vs Cold-Drink vs Temperature - Ice Cream Sale vs Temperature data.csv to Ice-Cream vs Cold-Drink vs Temperature - Ice Cream Sale vs Temperature data.csv
# Saving Size of TV,_Average time spent watching TV in a week (hours).csv to Size of TV,_Average time spent watching TV in a week (hours).csv
# Saving Student Marks vs Days Present.csv to Student Marks vs Days Present.csv
# ...

# %%
import csv
import numpy as np 


def getDataSource(data_path):
    coffee = []
    sleep = []
    with open(data_path) as csv_file:
        csv_reader = csv.DictReader(csv_file)
        for row in csv_reader:
           coffee.append(float(row["Coffee in ml"])) 
           sleep.append(float(row["sleep in hours"]))
    return {"X" : coffee, "Y" : sleep}


def findCorrelation(datasource):
    correlation = np.corrcoef(datasource["X"], datasource["Y"])
    print("The correlation between the amount of coffee drunk and sleep slept is: ", correlation[0,1])


def setup():
    data_path = "cups of coffee vs hours of sleep.csv"


    datasource = getDataSource(data_path)
    findCorrelation(datasource)
setup()
# Out:
# The correlation between the amount of coffee drunk and sleep slept is:  -0.9630614686000525
